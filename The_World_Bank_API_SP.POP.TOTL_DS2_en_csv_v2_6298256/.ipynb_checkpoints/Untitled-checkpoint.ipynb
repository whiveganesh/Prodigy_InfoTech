# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.plotting.register_matplotlib_converters()
# %matplotlib inline

sns.set_theme(palette='bright')
sns.set_context('notebook')
sns.set_style('darkgrid')

# %%
df = pd.read_csv("API_SP.POP.TOTL_DS2_en_csv_v2_6298256.csv", skiprows=3)
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2014         2015         2016         2017  \
# ...

# %%
# keys = df.columns
# values = df.values

# %%
# keys

# %%
# values

# %%
df.shape
# Out:
# (266, 68)

# %%
# df.info

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.172712e+08  1.188807e+08  1.210511e+08  1.237333e+08  1.264378e+08
# std    3.695439e+08  3.740897e+08  3.808061e+08  3.895039e+08  3.982439e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.132212e+05  5.231345e+05  5.337595e+05  5.449288e+05  5.566630e+05
# 50%    3.757486e+06  3.887144e+06  4.023896e+06  4.139356e+06  4.224612e+06
# 75%    2.670606e+07  2.748694e+07  2.830289e+07  2.914708e+07  3.001684e+07
# max    3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.291813e+08  1.320404e+08  1.348980e+08  1.378358e+08  1.408789e+08
# ...

# %%
df.drop(df.columns[-1], axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              2
#                  ..
# 2018              1
# 2019              1
# 2020              1
# 2021              1
# 2022              1
# Length: 67, dtype: int64

# %%
# import missingno as msno
# msno.matrix(df)

# %%
# column_null = df.columns[df.isnull().any()].tolist()
# column_null

# %%
df.dropna(inplace = True)

# %%
column_null = df.columns[df.isnull().any()].tolist()
column_null
# Out:
# []

# %%
df.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              0
#                  ..
# 2018              0
# 2019              0
# 2020              0
# 2021              0
# 2022              0
# Length: 67, dtype: int64

# %%
df.shape
# Out:
# (264, 67)

# %%
# # color = sns.color_palette(['#ff1493', '#ffffff'])
# plt.figure(figsize=(12,4))
# sns.heatmap(df.isnull(), cmap='viridis', cbar=True)
# plt.title("Null Value Visualize")
# plt.show()

# %%
print("Number of rows ...... {:5d}".format(df.shape[0]))
print("Number of columns  .. {:5d}".format(df.shape[1]))
# Out:
# Number of rows ......   264
# Number of columns  ..    67

# %%
df.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2018              float64
# 2019              float64
# 2020              float64
# 2021              float64
# 2022              float64
# Length: 67, dtype: object

# %%
df.columns[df.dtypes == 'categorical']
# Out:
# Index([], dtype='object')

# %%
selected_columns = df.iloc[:, 4:-1]
years = selected_columns.columns
values = selected_columns.values
years
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
values
# Out:
# array([[5.46080000e+04, 5.58110000e+04, 5.66820000e+04, ...,
#         1.06442000e+05, 1.06585000e+05, 1.06537000e+05],
#        [1.30692579e+08, 1.34169237e+08, 1.37835590e+08, ...,
#         6.67242986e+08, 6.85112979e+08, 7.02977106e+08],
#        [8.62246600e+06, 8.79014000e+06, 8.96904700e+06, ...,
#         3.77694990e+07, 3.89722300e+07, 4.00994620e+07],
#        ...,
#        [1.65204410e+07, 1.69894640e+07, 1.75031330e+07, ...,
#         5.80870550e+07, 5.88019270e+07, 5.93922550e+07],
#        [3.11943000e+06, 3.21945100e+06, 3.32342700e+06, ...,
#         1.83804770e+07, 1.89277150e+07, 1.94731250e+07],
#        [3.80631000e+06, 3.92595200e+06, 4.04977800e+06, ...,
#         1.53546080e+07, 1.56696660e+07, 1.59935240e+07]])

# %%
import matplotlib.pyplot as plt
import numpy as np

selected_columns = df.iloc[:, 4:-1]
years = selected_columns.columns
values = selected_columns.values

# Generate a list of distinct colors for each bar
colors = plt.cm.viridis(np.linspace(0, 1, len(years))) 

# Create a bar chart
plt.figure(figsize=(16,6))
plt.bar(years, values.mean(axis=0), color=colors)

# Customize the plot
plt.title('Bar Chart of Years')
plt.xlabel('Years')
plt.ylabel('Mean Values')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

selected_columns = df.iloc[:, 4:35]
years = selected_columns.columns
values = selected_columns.values

# Generate a list of distinct colors for each bar
colors = plt.cm.viridis(np.linspace(0, 1, len(years))) 

# Create a bar chart
plt.figure(figsize=(16,6))
plt.bar(years, values.mean(axis=0), color=colors)

# Customize the plot
plt.title('Bar Chart of Years')
plt.xlabel('Years')
plt.ylabel('Mean Values')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

selected_columns = df.iloc[:, 34:]
years = selected_columns.columns
values = selected_columns.values

# Generate a list of distinct colors for each bar
colors = plt.cm.viridis(np.linspace(0, 1, len(years))) 

# Create a bar chart
plt.figure(figsize=(16,6))
plt.bar(years, values.mean(axis=0), color=colors)

# Customize the plot
plt.title('Bar Chart of Years')
plt.xlabel('Years')
plt.ylabel('Mean Values')
plt.show()

# %%
selected_columns = df.columns[4:]
selected_columns
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %% [markdown]
# ### Compare the population growth rates of different countries or regions

# %%
selected_columns = df.columns[4:]
# Find the first available year in the selected columns
base_year = selected_columns[0]

for year in selected_columns:
    df[f"Growth Rate {year}"] = (df[year] - df[base_year]) / df[base_year] * 100

# Calculate average growth rates
df['Average Growth Rate'] = df.filter(like='Growth Rate').mean(axis=1)

growth_rate = df.loc[:, 'Growth Rate 1960':]
growth_rate
# Out:
#      Growth Rate 1960  Growth Rate 1961  Growth Rate 1962  Growth Rate 1963  \
# 0                 0.0          2.202974          3.797978          5.250146
# 1                 0.0          2.660180          5.465506          8.369233
# 2                 0.0          1.944618          4.019511          6.204710
# 3                 0.0          2.115789          4.306911          6.592095
# 4                 0.0          1.570561          3.065130          4.529087
# ..                ...               ...               ...               ...
# 261               0.0          2.006336          4.963041          7.919747
# 262               0.0          1.880194          3.805657          5.732798
# 263               0.0          2.839046          5.948340          9.211461
# 264               0.0          3.206387          6.539560         10.000256
# 265               0.0          3.143254          6.396431          9.763288
#
# ...

# %%
# print(df_ranked.columns)

# %%
# print(df_ranked.head())

# %%
# print(df_ranked.dtypes)

# %%
# Rank countries based on average growth rates
df_ranked = df.sort_values(by='Average Growth Rate', ascending=False)

# Print or visualize the results
print(df_ranked[['Country Name', 'Average Growth Rate']])
# Out:
#                   Country Name  Average Growth Rate
# 8         United Arab Emirates          2402.087811
# 200                      Qatar          2170.630798
# 225  Sint Maarten (Dutch part)           771.652929
# 56                    Djibouti           549.951184
# 127                     Kuwait           547.131894
# ..                         ...                  ...
# 54                     Czechia             6.511394
# 99                     Croatia             6.440100
# 21                    Bulgaria             3.213262
# 101                    Hungary             2.560549
# 125        St. Kitts and Nevis           -18.939259
#
# [264 rows x 2 columns]

# %%
# selecte_columns = df.loc[:,'1960':'2022':]
# # selecte_columns = df.loc[:,'Growth Rate 1960':'Growth Rate 2022']
# columns = selecte_columns.columns.tolist()
# columns

# %% [markdown]
# ### line plot

# %%
selected_columns = df.loc[:, '1960':'1970']
columns = selected_columns.columns.tolist()

# Assuming df_ranked is your DataFrame with 'Average Growth Rate' column
top_countries = df_ranked.head(10)

plt.figure(figsize=(10, 6))
for country in top_countries.index:
    plt.plot(columns, top_countries.loc[country, '1960':'1970'], marker='o', linestyle='-', label=top_countries.loc[country, 'Country Name'])

plt.title('Average Growth Rates Over Time (Top 32 Countries)')
plt.xlabel('Year')
plt.ylabel('Average Growth Rate')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')  # Place the legend outside the plot
plt.grid(True)
plt.show()

# %%
selected_columns = df.loc[:, '2000':'2022']
columns = selected_columns.columns.tolist()

# Assuming df_ranked is your DataFrame with 'Average Growth Rate' column
top_countries = df_ranked.head(22) 

plt.figure(figsize=(10, 6))
for country in top_countries.index:
    plt.plot(columns, top_countries.loc[country, '2000':'2022'], marker='o', linestyle='-', label=top_countries.loc[country, 'Country Name'])

plt.title('Average Growth Rates Over Time (Top 32 Countries)')
plt.xlabel('Year')
plt.ylabel('Average Growth Rate')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')  # Place the legend outside the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ### bar plot

# %%
import matplotlib.pyplot as plt
colors = plt.cm.viridis(np.linspace(0, 1, len(years))) 
# Plotting
plt.figure(figsize=(16, 6))
df_ranked[['Country Name', 'Average Growth Rate']].head(32).plot(kind='bar', x='Country Name', y='Average Growth Rate', color=colors, legend=False)
plt.title('Top 10 Countries by Average Growth Rate')
plt.xlabel('Country')
plt.ylabel('Average Growth Rate')
plt.show()

# %% [markdown]
# ### histogram plot

# %%
import matplotlib.pyplot as plt

# # Specify custom bin edges
# bin_edges = range(0, int(df_ranked['Average Growth Rate'].max()) + 100, 100) 
# Plotting histogram with custom bins
plt.figure(figsize=(10, 6))
plt.hist(df_ranked['Average Growth Rate'], bins=100, color='skyblue', edgecolor='black')
plt.title('Distribution of Average Growth Rates')
plt.xlabel('Average Growth Rate')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Identify countries or regions that experienced the highest or lowest population growth during specific periods.
#
#
# idxmin() returns the index where the minimum value occurs.
#
#
# idxmax() returns the index where the maximum value occurs.

# %%
periods_of_interest = [(1960, 1970), (1971, 1980), (1981, 1990), (1991, 2000), (2001, 2010), (2011, 2022)]
results = pd.DataFrame(columns=['Period', 'Country Name', 'Population Growth Rate'])
# Create an empty list to store DataFrames
result_dfs = []

for period in periods_of_interest:
    start_year, end_year = period
    period_name = f'{start_year}-{end_year}'

    # Calculate growth rate for the period
    df[f'Growth Rate_{period_name}'] = ((df[str(end_year)] - df[str(start_year)]) / df[str(start_year)]) * 100

    # Identify country with the highest growth rate
    highest_growth_country = df.loc[df[f'Growth Rate_{period_name}'].idxmax(), 'Country Name']
    highest_growth_rate = df.loc[df[f'Growth Rate_{period_name}'].idxmax()][f'Growth Rate_{period_name}']

    # Identify country with the lowest growth rate
    lowest_growth_country = df.loc[df[f'Growth Rate_{period_name}'].idxmin(), 'Country Name']
    lowest_growth_rate = df.loc[df[f'Growth Rate_{period_name}'].idxmin()][f'Growth Rate_{period_name}']


    # # Print information for the current period
    # print(f"Period: {period_name}")
    # print(f"Country with the Highest Growth: {highest_growth_country}, Growth Rate: {highest_growth_rate}")
    # print(f"Country with the Lowest Growth: {lowest_growth_country}, Growth Rate: {lowest_growth_rate}")
    # print()

    # Create a DataFrame for the current period
    period_df = pd.DataFrame({
        'Period': period_name,
        'Country Name (Highest Growth)': highest_growth_country,
        'Population Growth Rate (Highest)': highest_growth_rate,
        'Country Name (Lowest Growth)': lowest_growth_country,
        'Population Growth Rate (Lowest)': lowest_growth_rate
    }, index=[0])

    # Append the DataFrame to the list
    result_dfs.append(period_df)

# %%
# Concatenate all DataFrames in the list
results = pd.concat(result_dfs, ignore_index=True)
results
# Out:
#       Period Country Name (Highest Growth)  Population Growth Rate (Highest)  \
# 0  1960-1970                         Qatar                        224.328707
# 1  1971-1980          United Arab Emirates                        194.342449
# 2  1981-1990      St. Martin (French part)                        253.221148
# 3  1991-2000                   Afghanistan                         81.876950
# 4  2001-2010                         Qatar                        152.419822
# 5  2011-2022                        Jordan                         58.732781
#
#   Country Name (Lowest Growth)  Population Growth Rate (Lowest)
# 0          St. Kitts and Nevis                       -20.635369
# 1            Equatorial Guinea                        -9.438311
# 2          St. Kitts and Nevis                        -5.394268
# 3                      Georgia                       -15.690337
# 4     Northern Mariana Islands                       -31.948062
# ...

# %% [markdown]
# ### bar plot

# %%
# Create a bar plot for the highest growth rates
colors = plt.cm.viridis(np.linspace(0, 1, len(years)))
plt.figure(figsize=(10, 6))
plt.bar(results['Period'], results['Population Growth Rate (Highest)'], color=colors, label='Highest Growth Rate')
plt.title('Highest Population Growth Rate by Period')
plt.xlabel('Period')
plt.ylabel('Population Growth Rate (%)')
plt.legend()
plt.show()

# %%
# Create a bar plot for the lowest growth rates
plt.figure(figsize=(10, 6))
plt.bar(results['Period'], results['Population Growth Rate (Lowest)'], color='red', label='Lowest Growth Rate')
plt.title('Lowest Population Growth Rate by Period')
plt.xlabel('Period')
plt.ylabel('Population Growth Rate (%)')
plt.legend()
plt.show()

# %% [markdown]
# ### box plot

# %%
# Boxplot for Growth Rates by Period:
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x=results['Period'], y='Average Growth Rate', data=df_ranked, palette='viridis')
plt.title('Boxplot of Average Growth Rates by Period')
plt.xlabel('Period')
plt.ylabel('Average Growth Rate')
plt.show()

# %% [markdown]
# ### scatter plot

# %%
# Scatter Plot for Growth Rates by Period:
plt.figure(figsize=(10, 6))
plt.scatter(results['Population Growth Rate (Highest)'], results['Population Growth Rate (Lowest)'], color='purple')
plt.title('Scatter Plot of Highest vs. Lowest Growth Rates by Period')
plt.xlabel('Population Growth Rate (Highest)')
plt.ylabel('Population Growth Rate (Lowest)')
plt.show()

# %%
df['total_population'] = df.loc[:, '1960':'2022'].sum(axis=1)
df.head(5)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...  Growth Rate 2021  Growth Rate 2022  Average Growth Rate  \
# ...

# %% [markdown]
# ### Rank countries based on their population size for specific years.

# %%
# Select relevant data for the specified range of years (1960 to 1970)
selected_data = df[['Country Name', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970']]

# Calculate the average population for the specified years
selected_data['Average Population(1960-1970'] = selected_data[['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970']].mean(axis=1)

# Rank countries based on the average population
selected_data['Rank'] = selected_data['Average Population(1960-1970'].rank(ascending=False)

# Sort the DataFrame by rank
selected_data = selected_data.sort_values(by='Rank')

# Display the ranked data
print(selected_data[['Country Name', 'Average Population(1960-1970', 'Rank']])
# Out:
#                   Country Name  Average Population(1960-1970   Rank
# 259                      World                  3.338602e+09    1.0
# 103           IDA & IBRD total                  2.558823e+09    2.0
# 140        Low & middle income                  2.500876e+09    3.0
# 156              Middle income                  2.347078e+09    4.0
# 102                  IBRD only                  2.110219e+09    5.0
# ..                         ...                           ...    ...
# 179                      Nauru                  5.669545e+03  260.0
# 228   Turks and Caicos Islands                  5.645273e+03  261.0
# 245                     Tuvalu                  5.587000e+03  262.0
# 147   St. Martin (French part)                  4.916909e+03  263.0
# 225  Sint Maarten (Dutch part)                  4.275273e+03  264.0
#
# [264 rows x 3 columns]
# C:\Users\ganes\AppData\Local\Temp\ipykernel_17024\3814717842.py:5: SettingWithCopyWarning:
# ...

# %%
# Visualize changes in rankings over time for the top 10 countries
plt.figure(figsize=(10, 6))

# Select the top 10 countries
top_10_countries = selected_data.head(22)

for country in top_10_countries['Country Name']:
    country_data = selected_data[selected_data['Country Name'] == country]
    plt.plot(country_data['Average Population(1960-1970'], country_data['Rank'], label=country, marker='o')

plt.title('Average Population Rankings (1960 to 1970) - Top 10 Countries')
plt.xlabel('Average Population(1960-1970')
plt.ylabel('Rank')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %%
# Select relevant data for the specified range of years (2000 to 2022)
selected_data_2000_2022 = df[['Country Name'] + list(df.loc[:, '2000':'2022'].columns)]

# Calculate the average population for the specified years
selected_data_2000_2022['Average Population(2000-2022)'] = selected_data_2000_2022.loc[:, '2000':'2022'].mean(axis=1)

# Rank countries based on the average population
selected_data_2000_2022['Rank'] = selected_data_2000_2022['Average Population(2000-2022)'].rank(ascending=False)

# Sort the DataFrame by rank
selected_data_2000_2022 = selected_data_2000_2022.sort_values(by='Rank')

# Display the ranked data
print(selected_data_2000_2022[['Country Name', 'Average Population(2000-2022)', 'Rank']])
# Out:
#                Country Name  Average Population(2000-2022)   Rank
# 259                   World                   7.059815e+09    1.0
# 103        IDA & IBRD total                   5.928042e+09    2.0
# 140     Low & middle income                   5.850421e+09    3.0
# 156           Middle income                   5.319998e+09    4.0
# 102               IBRD only                   4.472633e+09    5.0
# ..                      ...                            ...    ...
# 84                Gibraltar                   3.092865e+04  260.0
# 255  British Virgin Islands                   2.686652e+04  261.0
# 188                   Palau                   1.867570e+04  262.0
# 179                   Nauru                   1.093830e+04  263.0
# 245                  Tuvalu                   1.047748e+04  264.0
#
# [264 rows x 3 columns]
# C:\Users\ganes\AppData\Local\Temp\ipykernel_17024\542042424.py:5: SettingWithCopyWarning:
# ...

# %% [markdown]
# ### line char

# %%
# Visualize changes in rankings over time for the top 10 countries
plt.figure(figsize=(10, 6))

# Select the top 10 countries
top_10_countries = selected_data_2000_2022.head(22)

for country in top_10_countries['Country Name']:
    country_data = selected_data_2000_2022[selected_data_2000_2022['Country Name'] == country]
    plt.plot(country_data['Average Population(2000-2022)'], country_data['Rank'], label=country, marker='o')

plt.title('Average Population Rankings (1960 to 1970) - Top 10 Countries')
plt.xlabel('Average Population(2000-2022)')
plt.ylabel('Rank')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Identify changes in population rankings over time.

# %%
# Rank countries based on the average population for each year
for year in range(2010, 2022):
    selected_data_2000_2022[f'Rank_{year}'] = selected_data_2000_2022[str(year)].rank(ascending=False)

# Display the ranked data for the selected years
print(selected_data_2000_2022[['Country Name'] + [f'Rank_{year}' for year in range(2010, 2022)]])
# Out:
#                Country Name  Rank_2010  Rank_2011  Rank_2012  Rank_2013  \
# 259                   World        1.0        1.0        1.0        1.0
# 103        IDA & IBRD total        2.0        2.0        2.0        2.0
# 140     Low & middle income        3.0        3.0        3.0        3.0
# 156           Middle income        4.0        4.0        4.0        4.0
# 102               IBRD only        5.0        5.0        5.0        5.0
# ..                      ...        ...        ...        ...        ...
# 84                Gibraltar      259.0      259.0      259.0      260.0
# 255  British Virgin Islands      261.0      261.0      261.0      261.0
# 188                   Palau      262.0      262.0      262.0      262.0
# 179                   Nauru      264.0      264.0      264.0      264.0
# 245                  Tuvalu      263.0      263.0      263.0      263.0
#
#      Rank_2014  Rank_2015  Rank_2016  Rank_2017  Rank_2018  Rank_2019  \
# ...

# %% [markdown]
# ### line char

# %%
# Visualize changes in rankings over time for a specific country (e.g., 'United States')
country_name = 'United Arab Emirates'
plt.figure(figsize=(10, 6))
for year in range(2010, 2022):
    plt.plot(selected_data_2000_2022[f'Rank_{year}'], label=str(year), marker='o')

plt.title(f'Population Rankings Over Time for {country_name}')
plt.xlabel('Year')
plt.ylabel('Rank')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# ### heat map

# %%
# Select relevant columns for the heatmap
heatmap_data = selected_data_2000_2022[['Country Name'] + [f'Rank_{year}' for year in range(2010, 2022)]]

# Set 'Country Name' as the index
heatmap_data = heatmap_data.set_index('Country Name')

# Transpose the DataFrame to have years as rows and countries as columns
heatmap_data_transposed = heatmap_data.T

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data_transposed, cmap='YlGnBu', annot=True, fmt=".0f", linewidths=.5)
plt.title(f'Population Rankings Over Time for {country_name}')
plt.xlabel('Country')
plt.ylabel('Rank')
plt.show()
